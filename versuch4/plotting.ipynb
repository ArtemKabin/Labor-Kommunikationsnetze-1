# %% [markdown]
# # Versuch 4

# %% [markdown]
# By specifying the path to a cnl_file, you can run the scripts cnl_plot.py and summary.py in this notebook, which also allows the plots to be presented.

# %% [markdown]
# ## Aufgabe 1.1
#
# ```bash
# labrat@c1:~$ iperf3 -c 10.11.0.3 -Z
# Connecting to host 10.11.0.3, port 5201
# [  5] local 10.11.0.1 port 43896 connected to 10.11.0.3 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec   297 KBytes  2.43 Mbits/sec    0   31.1 KBytes
# [  5]   1.00-2.00   sec  63.6 KBytes   521 Kbits/sec    0   31.1 KBytes
# [  5]   2.00-3.00   sec   127 KBytes  1.04 Mbits/sec    0   31.1 KBytes
# [  5]   3.00-4.00   sec   127 KBytes  1.04 Mbits/sec    0   31.1 KBytes
# [  5]   4.00-5.00   sec   127 KBytes  1.05 Mbits/sec    0   31.1 KBytes
# [  5]   5.00-6.00   sec   127 KBytes  1.04 Mbits/sec    0   31.1 KBytes
# [  5]   6.00-7.00   sec   127 KBytes  1.04 Mbits/sec    0   31.1 KBytes
# [  5]   7.00-8.00   sec  63.6 KBytes   519 Kbits/sec    0   31.1 KBytes
# [  5]   8.00-9.00   sec   127 KBytes  1.04 Mbits/sec    0   31.1 KBytes
# [  5]   9.00-10.00  sec   127 KBytes  1.04 Mbits/sec    0   31.1 KBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec  1.28 MBytes  1.08 Mbits/sec    0             sender
# [  5]   0.00-10.10  sec  1.15 MBytes   953 Kbits/sec                  receiver
#
# iperf Done.
# ```

# %%
import os

# %% [markdown]
# ## Aufgabe 1.2

# %%
# %run /CPUnetPLOT/cnl_plot.py  -nsc 0.0011 /tmp/cpunetlog/2025-06-15_11:49:29-ubuntu.cnl
# Out:
# /tmp/cpunetlog/2025-06-15_11:49:29-ubuntu.cnl
# {
#     "Classes": [
#         "Time",
#         "CPU",
#         "NIC"
#     ],
#     "Comment": null,
#     "Date": [
#         "2025-06-15_11:49:29",
#         1749988169.802952
#     ],
#     "Environment": null,
#     "SystemInfo": {
#         "hostname": "ubuntu",
#         "kernel": "5.15.0-139-generic",
#         "machine": "aarch64",
#         "sysname": "Linux",
#         "version": "#149-Ubuntu SMP Fri Apr 11 22:07:32 UTC 2025"
#     },
#     "Type": "CPUnetLOG:MeasurementLog"
# }

# %% [markdown]
# ## Aufgabe 1.3

# %%
# %run /CPUnetPLOT/summary.py /tmp/cpunetlog/2025-06-15_11:49:29-ubuntu.cnl
# Out:
# === Summary ===
# Filename:  2025-06-15_11:49:29-ubuntu.cnl
# Comment:
# Hostname:  ubuntu
# Kernel:    5.15.0-139-generic
#
# Start:     2025-06-15_11:49:35
# End:       2025-06-15_11:49:46
# Duration:  11
#
# CPUs: CPU0, CPU1
# NICs: sv1-eth1
#
# == Average transmission rates ==
# sv1-eth1.send:       0.02 MBits/s
# sv1-eth1.receive:       0.92 MBits/s

# %% [markdown]
# ## Aufgabe 2.1

# %%
# %run /CPUnetPLOT/cnl_plot.py  -nsc 0.0011 /tmp/cpunetlog/2025-06-15_12:02:35-ubuntu.cnl
# Out:
# /tmp/cpunetlog/2025-06-15_12:02:35-ubuntu.cnl
# {
#     "Classes": [
#         "Time",
#         "CPU",
#         "NIC"
#     ],
#     "Comment": null,
#     "Date": [
#         "2025-06-15_12:02:35",
#         1749988955.6231296
#     ],
#     "Environment": null,
#     "SystemInfo": {
#         "hostname": "ubuntu",
#         "kernel": "5.15.0-139-generic",
#         "machine": "aarch64",
#         "sysname": "Linux",
#         "version": "#149-Ubuntu SMP Fri Apr 11 22:07:32 UTC 2025"
#     },
#     "Type": "CPUnetLOG:MeasurementLog"
# }

# %% [markdown]
# ## Aufgabe 2.4

# %%
# %run /CPUnetPLOT/cnl_plot.py  -nsc 0.0011 /tmp/cpunetlog/2025-06-15_12:08:07-ubuntu.cnl
# Out:
# /tmp/cpunetlog/2025-06-15_12:08:07-ubuntu.cnl
# {
#     "Classes": [
#         "Time",
#         "CPU",
#         "NIC"
#     ],
#     "Comment": null,
#     "Date": [
#         "2025-06-15_12:08:07",
#         1749989287.34511
#     ],
#     "Environment": null,
#     "SystemInfo": {
#         "hostname": "ubuntu",
#         "kernel": "5.15.0-139-generic",
#         "machine": "aarch64",
#         "sysname": "Linux",
#         "version": "#149-Ubuntu SMP Fri Apr 11 22:07:32 UTC 2025"
#     },
#     "Type": "CPUnetLOG:MeasurementLog"
# }
